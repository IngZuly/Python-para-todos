# %% [markdown]
# <a href="https://colab.research.google.com/github/IngZuly/Python-para-todos/blob/main/trabajo_en_clase_260226.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Listas como Arreglos

# %%
estatura=[1.82,1.78,1.81,1.60,1.57]
print("el cuarto elemento es:",estatura[3])
print("el ultimo elemento es:",estatura[-1])
for x in estatura:
  print(x)
print (x)
# Out:
# el cuarto elemento es: 1.6
# el ultimo elemento es: 1.57
# 1.82
# 1.78
# 1.81
# 1.6
# 1.57
# 1.57

# %% [markdown]
# Arreglos con Numpy

# %%
import numpy as np
calificaciones= np.array([70,85,92,100,75])
print(f"Arreglo original {calificaciones}")
# Out:
# Arreglo original [ 70  85  92 100  75]
